# %%
import pandas as pd

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('default of credit card clients.xls', header=1)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df['SEX'] = df['SEX'].map({1: 0, 2: 1})

#changing male from 1 to 0 and female from 2 to 1 for clarity

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    1          2         1   24      2      2     -1     -1
# 1   2     120000    1          2         2   26     -1      2      0      0
# 2   3      90000    1          2         2   34      0      0      0      0
# 3   4      50000    1          2         1   37      0      0      0      0
# 4   5      50000    0          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df['EDUCATION'] = df['EDUCATION'].replace({1:0, 2:1, 3:2, 4:3})

# %%
df['MARRIAGE'] = df['MARRIAGE'].replace({1:0, 2:1, 3:2})

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    1          1         0   24      2      2     -1     -1
# 1   2     120000    1          1         0   26     -1      2      0      0
# 2   3      90000    1          1         0   34      0      0      0      0
# 3   4      50000    1          1         0   37      0      0      0      0
# 4   5      50000    0          1         0   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    1          1         0   24      2      2     -1
# 1          2     120000    1          1         0   26     -1      2      0
# 2          3      90000    1          1         0   34      0      0      0
# 3          4      50000    1          1         0   37      0      0      0
# 4          5      50000    0          1         0   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    0          2         0   39      0      0      0
# 29996  29997     150000    0          2         0   43     -1     -1     -1
# 29997  29998      30000    0          1         0   37      4      3      2
# 29998  29999      80000    0          2         0   41      1     -1      0
# 29999  30000      50000    0          1         0   46      0      0      0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.rename(columns={'PAY_0': 'PAY_1'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['LIMIT_BAL'])
plt.title('Boxplot of LIMIT_BAL')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['PAY_1'])
plt.title('Boxplot for PAY_1')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df['BILL_AMT1'])
plt.title('Boxplot of Bill Amount')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x= df['PAY_AMT1'])
plt.title('Boxplot of Pay Amount')
plt.show()

# %%
numeric_cols = ['LIMIT_BAL']+\
               [f'BILL_AMT{i}' for i in range(1,7)] + \
               [f'PAY_AMT{i}' for i in range(1,7)] +\
               [f'AGE']

# %%
scaler = StandardScaler()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df[numeric_cols].describe()
# Out:
#           LIMIT_BAL     BILL_AMT1     BILL_AMT2     BILL_AMT3     BILL_AMT4  \
# count  3.000000e+04  3.000000e+04  3.000000e+04  3.000000e+04  3.000000e+04
# mean  -3.789561e-18 -1.042129e-17 -1.089499e-17 -1.231607e-17 -3.789561e-18
# std    1.000017e+00  1.000017e+00  1.000017e+00  1.000017e+00  1.000017e+00
# min   -1.213794e+00 -2.944312e+00 -1.671375e+00 -2.945672e+00 -3.315048e+00
# 25%   -9.054983e-01 -6.473120e-01 -6.490466e-01 -6.394814e-01 -6.363293e-01
# 50%   -2.118326e-01 -3.916884e-01 -3.931159e-01 -3.882529e-01 -3.763451e-01
# 75%    5.589071e-01  2.154919e-01  2.083271e-01  1.896457e-01  1.747667e-01
# max    6.416528e+00  1.240296e+01  1.313360e+01  2.331820e+01  1.318669e+01
#
#           BILL_AMT5     BILL_AMT6      PAY_AMT1      PAY_AMT2      PAY_AMT3  \
# count  3.000000e+04  3.000000e+04  3.000000e+04  3.000000e+04  3.000000e+04
# mean  -1.136868e-17  6.631732e-18 -2.842171e-18  3.789561e-18  5.684342e-18
# ...

# %%
df[numeric_cols].mean()
# Out:
# LIMIT_BAL   -3.789561e-18
# BILL_AMT1   -7.579123e-18
# BILL_AMT2   -1.089499e-17
# BILL_AMT3   -1.136868e-17
# BILL_AMT4   -3.789561e-18
# BILL_AMT5   -1.136868e-17
# BILL_AMT6    5.684342e-18
# PAY_AMT1    -2.842171e-18
# PAY_AMT2     3.315866e-18
# PAY_AMT3     5.684342e-18
# PAY_AMT4     2.368476e-18
# PAY_AMT5    -4.026409e-18
# PAY_AMT6    -4.144833e-18
# AGE         -1.856885e-16
# dtype: float64

# %%
df.drop(columns=['ID'],inplace=True)
#variable ID is not needed in model building. missed in the first place.

# %%
#splitting the data into feature and target & train and test

# %%
x=df.drop(columns=['default payment next month'])
y=df['default payment next month']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42, stratify=y)

# %%
from sklearn.model_selection import train_test_split

# %%
print('train shape',x_train.shape)
print('test shape', x_test.shape)
# Out:
# train shape (24000, 23)
# test shape (6000, 23)

# %%
print('train target distribution:\n', y_train.value_counts(normalize=True))
print('test terget distribution:\n',y_test.value_counts(normalize=True))
# Out:
# train target distribution:
#  default payment next month
# 0    0.778792
# 1    0.221208
# Name: proportion, dtype: float64
# test terget distribution:
#  default payment next month
# 0    0.778833
# 1    0.221167
# Name: proportion, dtype: float64

# %%
#building model, logistic regression, predicting default chances in binary, that is from 0(no default) to 1(default)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
lr_predd_y = lr.predict(x_test)
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=30000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=30000)

# %%
from sklearn.pipeline import make_pipeline

# %%
model = make_pipeline(
    StandardScaler(),                      
    LogisticRegression(max_iter=1000)  
)

# %%
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=1000))])

# %%
print(x_train.describe())
# Out:
#           LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count  24000.000000  24000.000000  24000.000000  24000.000000  24000.000000
# mean      -0.000922      0.604750      0.865833      0.010625     35.432625
# std        0.998195      0.488915      0.845002      0.102531      9.195256
# min       -1.213794      0.000000      0.000000      0.000000     21.000000
# 25%       -0.905498      0.000000      0.000000      0.000000     28.000000
# 50%       -0.211833      1.000000      1.000000      0.000000     34.000000
# 75%        0.558907      1.000000      1.000000      0.000000     41.000000
# max        6.416528      1.000000      6.000000      1.000000     75.000000
#
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  24000.000000  24000.000000  24000.000000  24000.000000  24000.000000
# mean      -0.014125     -0.134083     -0.166917     -0.221333     -0.270333
# ...

# %%
scaler = StandardScaler()
df['AGE'] = scaler.fit_transform(df['AGE'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 2
#       1 scaler = StandardScaler()
# ----> 2 df['AGE'] = scaler.fit_transform(df['AGE'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     903         warnings.warn(
# ...
